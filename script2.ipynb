# %%
import pandas as pd

# %%
df = pd.read_csv("prices_round_0_day_-1.csv", sep=";")

# %%
df[df["product"]=="TOMATOES"].bid_price_1.mean()
# Out:
# np.float64(4971.0801)

# %%
df[df["product"]=="EMERALDS"].bid_price_1.mean()
# Out:
# np.float64(9992.1264)

# %%
df[df["product"]=="EMERALDS"].bid_price_1.mean()
# Out:
# np.float64(9992.1264)

# %%
df[df["product"]=="TOMATOES"].bid_price_1.min()
# Out:
# np.int64(4941)

# %%
df[df["product"]=="TOMATOES"].bid_price_1.max()
# Out:
# np.int64(5008)

# %%
df[df["product"]=="EMERALDS"].bid_price_1.min()
# Out:
# np.int64(9992)

# %%
df[df["product"]=="EMERALDS"].bid_price_1.max()
# Out:
# np.int64(10000)

# %%
df2 = pd.read_csv("prices_round_0_day_-2.csv", sep=";")

# %%
df2[df2["product"]=="EMERALDS"].bid_price_1.mean()
# Out:
# np.float64(9992.1304)

# %%
df2.head(20)
# Out:
#     day  timestamp   product  bid_price_1  bid_volume_1  bid_price_2  \
# 0    -2          0  EMERALDS         9992            11         9990
# 1    -2          0  TOMATOES         4993             7         4992
# 2    -2        100  TOMATOES         4998             5         4993
# 3    -2        100  EMERALDS         9992            15         9990
# 4    -2        200  TOMATOES         4994             6         4993
# 5    -2        200  EMERALDS         9992            15         9990
# 6    -2        300  EMERALDS         9992            13         9990
# 7    -2        300  TOMATOES         4995             5         4993
# 8    -2        400  EMERALDS         9992            15         9990
# 9    -2        400  TOMATOES         4995             8         4993
# 10   -2        500  TOMATOES         4994             6         4993
# 11   -2        500  EMERALDS         9992            13         9990
# 12   -2        600  TOMATOES         4994             9         4992
# ...

# %%
df.query("product=='EMERALDS'").head(20)
# Out:
#     day  timestamp   product  bid_price_1  bid_volume_1  bid_price_2  \
# 1    -1          0  EMERALDS         9992            14         9990
# 2    -1        100  EMERALDS         9992            11         9990
# 4    -1        200  EMERALDS         9992            15         9990
# 7    -1        300  EMERALDS         9992            11         9990
# 9    -1        400  EMERALDS         9992            12         9990
# 10   -1        500  EMERALDS         9992            12         9990
# 12   -1        600  EMERALDS         9992            11         9990
# 15   -1        700  EMERALDS         9992            12         9990
# 17   -1        800  EMERALDS         9992            15         9990
# 18   -1        900  EMERALDS         9992            15         9990
# 20   -1       1000  EMERALDS         9992            13         9990
# 23   -1       1100  EMERALDS         9992            12         9990
# 25   -1       1200  EMERALDS         9992            11         9990
# ...

# %%
df.query("product=='TOMATOES'").head(20)
# Out:
#     day  timestamp   product  bid_price_1  bid_volume_1  bid_price_2  \
# 0    -1          0  TOMATOES         4999             5         4998
# 3    -1        100  TOMATOES         5000             8         4998
# 5    -1        200  TOMATOES         5000            10         4999
# 6    -1        300  TOMATOES         5000             9         4999
# 8    -1        400  TOMATOES         5000             5         4999
# 11   -1        500  TOMATOES         5000             6         4999
# 13   -1        600  TOMATOES         5005             5         5000
# 14   -1        700  TOMATOES         5000            10         4999
# 16   -1        800  TOMATOES         5000             8         4998
# 19   -1        900  TOMATOES         5000             6         4998
# 21   -1       1000  TOMATOES         5000             7         4999
# 22   -1       1100  TOMATOES         5007             8         5000
# 24   -1       1200  TOMATOES         5000             6         4999
# ...

# %%
df.shape
# Out:
# (20000, 17)

# %%
bid_spike = df.query("product=='TOMATOES' and bid_price_1-bid_price_2>4")

# %%
bid_spike.shape
# Out:
# (363, 17)

# %%
ask_spike = df.query("product=='TOMATOES' and ask_price_2-ask_price_1>4")

# %%
bid_spike
# Out:
#        day  timestamp   product  bid_price_1  bid_volume_1  bid_price_2  \
# 13      -1        600  TOMATOES         5005             5         5000
# 22      -1       1100  TOMATOES         5007             8         5000
# 30      -1       1500  TOMATOES         5008             8         5000
# 114     -1       5700  TOMATOES         5003             8         4995
# 274     -1      13700  TOMATOES         5006             5         4998
# ...    ...        ...       ...          ...           ...          ...
# 19854   -1     992700  TOMATOES         4949             6         4944
# 19856   -1     992800  TOMATOES         4951            10         4944
# 19936   -1     996800  TOMATOES         4950             2         4945
# 19990   -1     999500  TOMATOES         4955             5         4950
# 19993   -1     999600  TOMATOES         4955             5         4949
#
#        bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
ask_spike
# Out:
#        day  timestamp   product  bid_price_1  bid_volume_1  bid_price_2  \
# 86      -1       4300  TOMATOES         4995             6         4994
# 212     -1      10600  TOMATOES         5002             6         5000
# 236     -1      11800  TOMATOES         4999             8         4997
# 278     -1      13900  TOMATOES         4997             9         4996
# 293     -1      14600  TOMATOES         4997             9         4995
# ...    ...        ...       ...          ...           ...          ...
# 19920   -1     996000  TOMATOES         4943             7         4942
# 19925   -1     996200  TOMATOES         4943             9         4942
# 19931   -1     996500  TOMATOES         4943             8         4942
# 19933   -1     996600  TOMATOES         4944             6         4942
# 19941   -1     997000  TOMATOES         4945             7         4944
#
#        bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
df
# Out:
#        day  timestamp   product  bid_price_1  bid_volume_1  bid_price_2  \
# 0       -1          0  TOMATOES         4999             5         4998
# 1       -1          0  EMERALDS         9992            14         9990
# 2       -1        100  EMERALDS         9992            11         9990
# 3       -1        100  TOMATOES         5000             8         4998
# 4       -1        200  EMERALDS         9992            15         9990
# ...    ...        ...       ...          ...           ...          ...
# 19995   -1     999700  EMERALDS         9992            12         9990
# 19996   -1     999800  EMERALDS         9992            13         9990
# 19997   -1     999800  TOMATOES         4951             6         4949
# 19998   -1     999900  TOMATOES         4950            10         4949
# 19999   -1     999900  EMERALDS         9992            10         9990
#
#        bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
df["spread"] = df["ask_price_1"] - df["bid_price_1"]

# %%
df
# Out:
#        day  timestamp   product  bid_price_1  bid_volume_1  bid_price_2  \
# 0       -1          0  TOMATOES         4999             5         4998
# 1       -1          0  EMERALDS         9992            14         9990
# 2       -1        100  EMERALDS         9992            11         9990
# 3       -1        100  TOMATOES         5000             8         4998
# 4       -1        200  EMERALDS         9992            15         9990
# ...    ...        ...       ...          ...           ...          ...
# 19995   -1     999700  EMERALDS         9992            12         9990
# 19996   -1     999800  EMERALDS         9992            13         9990
# 19997   -1     999800  TOMATOES         4951             6         4949
# 19998   -1     999900  TOMATOES         4950            10         4949
# 19999   -1     999900  EMERALDS         9992            10         9990
#
#        bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
tf = df.query("product=='TOMATOES'")

# %%
tf
# Out:
#        day  timestamp   product  bid_price_1  bid_volume_1  bid_price_2  \
# 0       -1          0  TOMATOES         4999             5         4998
# 3       -1        100  TOMATOES         5000             8         4998
# 5       -1        200  TOMATOES         5000            10         4999
# 6       -1        300  TOMATOES         5000             9         4999
# 8       -1        400  TOMATOES         5000             5         4999
# ...    ...        ...       ...          ...           ...          ...
# 19990   -1     999500  TOMATOES         4955             5         4950
# 19993   -1     999600  TOMATOES         4955             5         4949
# 19994   -1     999700  TOMATOES         4950            10         4948
# 19997   -1     999800  TOMATOES         4951             6         4949
# 19998   -1     999900  TOMATOES         4950            10         4949
#
#        bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
tf["spread"].value_counts()
# Out:
# spread
# 13    5214
# 14    4064
# 8      236
# 7      206
# 6      137
# 5       91
# 9       52
# Name: count, dtype: int64

# %%
tf.query("spread<=8").head(50)
# Out:
#       day  timestamp   product  bid_price_1  bid_volume_1  bid_price_2  \
# 22     -1       1100  TOMATOES         5007             8         5000
# 30     -1       1500  TOMATOES         5008             8         5000
# 86     -1       4300  TOMATOES         4995             6         4994
# 114    -1       5700  TOMATOES         5003             8         4995
# 212    -1      10600  TOMATOES         5002             6         5000
# 236    -1      11800  TOMATOES         4999             8         4997
# 274    -1      13700  TOMATOES         5006             5         4998
# 278    -1      13900  TOMATOES         4997             9         4996
# 293    -1      14600  TOMATOES         4997             9         4995
# 299    -1      14900  TOMATOES         5001             4         4996
# 318    -1      15900  TOMATOES         4998             5         4996
# 323    -1      16100  TOMATOES         4997            10         4996
# ...

# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(tf.query("spread<=8"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\PycharmProjects\pev-bj\.venv2\Lib\site-packages\matplotlib\axis.py:1811, in Axis.convert_units(self, x)
#    1810 try:
# -> 1811     ret = self._converter.convert(x, self.units, self)
#    1812 except Exception as e:
#
# File ~\PycharmProjects\pev-bj\.venv2\Lib\site-packages\matplotlib\category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#      48 if unit is None:
# ---> 49     raise ValueError(
#      50         'Missing category information for StrCategoryConverter; '
#      51         'this might be caused by unintendedly mixing categorical and '
#      52         'numeric data')
#      53 StrCategoryConverter._validate_unit(unit)
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# ...
